# %%
# %load_ext autoreload
# %autoreload 2
from task import *
from GA import Model
from crossover import *
from mutation import *
from local_search import *
import pandas as pd
from tqdm import tqdm
import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_run = 10

# %%
def run_task_twocut(task_type, task_id, num_run, pop_sizes: List[int], num_lss: List[int]):
	counter = 0
	for i in range(num_run):
		if task_type == "small":
			task = load_small_task(task_id)
		elif task_type == "medium":
			task = load_medium_task(task_id)
		else:
			task = load_large_task(task_id)

		for pop_size in pop_sizes:
			for num_ls in num_lss:
				start_time = time.time()
				counter += 1
				np.random.seed(counter)
				
				model = Model(pop_size=pop_size, 
						task=task, 
						crossover=TwoCutCrossover(), 
						mutation=InsertionMutation(), 
						localsearch=SimpleLocalSearch())
				bfs, _ = model.fit(num_gen=1000, 
								num_crossover=pop_size, 
								num_mutation=int(pop_size * 0.05), 
								num_ls=num_ls, 
								monitor=False)
				bfs = np.array(bfs)
				df = pd.DataFrame(bfs.T)
				df.to_csv("result/twocut/" + task_type + "/" + "task_{0}_popsize{1}_numls{2}_{3}".format(task_id, pop_size, num_ls, i))
				print("Task {0}, num run {1}, pop size {2}, num ls {3}, time taken: {4:0.3f}s".format(task_id, i, pop_size, num_ls, time.time() - start_time))

# %%
def run_task_comb(task_type, task_id, num_run, pop_sizes: List[int], num_lss: List[int]):
	counter = 0
	for i in range(num_run):
		if task_type == "small":
			task = load_small_task(task_id)
		elif task_type == "medium":
			task = load_medium_task(task_id)
		else:
			task = load_large_task(task_id)

		for pop_size in pop_sizes:
			for num_ls in num_lss:
				start_time = time.time()
				counter += 1
				np.random.seed(counter)
				
				model = Model(pop_size=pop_size, 
						task=task, 
						crossover=CombinatorialCrossover(), 
						mutation=InsertionMutation(), 
						localsearch=SimpleLocalSearch())
				bfs, _ = model.fit(num_gen=1000, 
								num_crossover=pop_size, 
								num_mutation=int(pop_size * 0.05), 
								num_ls=num_ls, 
								monitor=False)
				bfs = np.array(bfs)
				df = pd.DataFrame(bfs.T)
				df.to_csv("result/combinatorial/" + task_type + "/" + "task_{0}_popsize{1}_numls{2}_{3}".format(task_id, pop_size, num_ls, i))
				print("Task {0}, num run {1}, pop size {2}, num ls {3}, time taken: {4:0.3f}s".format(task_id, i, pop_size, num_ls, time.time() - start_time))

# %% [markdown]
# ### Small

# %% [markdown]
# #### Two Cut Crossover

# %%
for task_id in range(5):
    run_task_twocut("small", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
# Out:
# Task 0, num run 0, pop size 100, num ls 0, time taken: 0.800s
# Task 0, num run 0, pop size 100, num ls 10, time taken: 1.515s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for task_id in range(5):
# ----> 2     run_task_twocut("small", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
#
# Cell In[4], line 22, in run_task_twocut(task_type, task_id, num_run, pop_sizes, num_lss)
#      15 np.random.seed(counter)
#      17 model = Model(pop_size=pop_size,
#      18 		task=task,
#      19 		crossover=TwoCutCrossover(),
#      20 		mutation=InsertionMutation(),
#      21 		localsearch=SimpleLocalSearch())
# ---> 22 bfs, _ = model.fit(num_gen=1000,
#      23 				num_crossover=pop_size,
#      24 				num_mutation=int(pop_size * 0.05),
#      25 				num_ls=num_ls,
#      26 				monitor=False)
#      27 bfs = np.array(bfs)
#      28 df = pd.DataFrame(bfs.T)
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\GA.py:47, in Model.fit(self, num_gen, num_crossover, num_mutation, num_ls, monitor, monitor_rate)
#      45 pa = self.get_random_indi()
#      46 pb = self.get_random_indi()
# ---> 47 oc = self.crossover(pa, pb) #crossover offspring
#      48 while oc.check_valid() == False:
#      49     oc.fix()
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\crossover\twocut.py:32, in TwoCutCrossover.__call__(self, pa, pb)
#      31 def __call__(self, pa:Individual, pb:Individual) -> Individual:
# ---> 32     return self.crossover(pa, pb)
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\crossover\twocut.py:14, in TwoCutCrossover.crossover(self, pa, pb)
#      11 gene_o = gene_a.copy()
#      13 deli_types_o = pa.deli_types.copy()
# ---> 14 rnd = np.random.uniform(size=deli_types_o.shape)
#      15 deli_types_o[rnd < 0.5] = pb.deli_types[rnd < 0.5]
#      17 fi_cut : int = np.random.randint(0, pa.task.num_customers) * 3
#
# KeyboardInterrupt:

# %% [markdown]
# #### Combinatorial Crossover

# %%
for task_id in range(5):
    run_task_comb("small", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
# Out:
# Task 0, num run 0, pop size 100, num ls 0, time taken: 0.890s
# Task 0, num run 0, pop size 100, num ls 10, time taken: 1.307s
# Task 0, num run 0, pop size 200, num ls 0, time taken: 1.797s
# Task 0, num run 0, pop size 200, num ls 10, time taken: 2.684s
# Task 0, num run 1, pop size 100, num ls 0, time taken: 1.260s
# Task 0, num run 1, pop size 100, num ls 10, time taken: 1.718s
# Task 0, num run 1, pop size 200, num ls 0, time taken: 1.679s
# Task 0, num run 1, pop size 200, num ls 10, time taken: 2.002s
# Task 0, num run 2, pop size 100, num ls 0, time taken: 1.076s
# Task 0, num run 2, pop size 100, num ls 10, time taken: 1.312s
# Task 0, num run 2, pop size 200, num ls 0, time taken: 1.829s
# Task 0, num run 2, pop size 200, num ls 10, time taken: 2.290s
# Task 0, num run 3, pop size 100, num ls 0, time taken: 0.921s
# Task 0, num run 3, pop size 100, num ls 10, time taken: 1.391s
# Task 0, num run 3, pop size 200, num ls 0, time taken: 1.729s
# Task 0, num run 3, pop size 200, num ls 10, time taken: 2.171s
# Task 0, num run 4, pop size 100, num ls 0, time taken: 0.975s
# Task 0, num run 4, pop size 100, num ls 10, time taken: 1.270s
# Task 0, num run 4, pop size 200, num ls 0, time taken: 2.049s
# Task 0, num run 4, pop size 200, num ls 10, time taken: 2.317s
# Task 0, num run 5, pop size 100, num ls 0, time taken: 0.828s
# Task 0, num run 5, pop size 100, num ls 10, time taken: 1.553s
# Task 0, num run 5, pop size 200, num ls 0, time taken: 1.976s
# Task 0, num run 5, pop size 200, num ls 10, time taken: 2.361s
# Task 0, num run 6, pop size 100, num ls 0, time taken: 0.937s
# Task 0, num run 6, pop size 100, num ls 10, time taken: 1.327s
# Task 0, num run 6, pop size 200, num ls 0, time taken: 1.821s
# Task 0, num run 6, pop size 200, num ls 10, time taken: 2.092s
# Task 0, num run 7, pop size 100, num ls 0, time taken: 0.904s
# Task 0, num run 7, pop size 100, num ls 10, time taken: 1.358s
# Task 0, num run 7, pop size 200, num ls 0, time taken: 1.622s
# Task 0, num run 7, pop size 200, num ls 10, time taken: 2.109s
# Task 0, num run 8, pop size 100, num ls 0, time taken: 1.043s
# Task 0, num run 8, pop size 100, num ls 10, time taken: 1.385s
# Task 0, num run 8, pop size 200, num ls 0, time taken: 1.971s
# Task 0, num run 8, pop size 200, num ls 10, time taken: 1.952s
# Task 0, num run 9, pop size 100, num ls 0, time taken: 0.954s
# Task 0, num run 9, pop size 100, num ls 10, time taken: 1.636s
# Task 0, num run 9, pop size 200, num ls 0, time taken: 1.728s
# Task 0, num run 9, pop size 200, num ls 10, time taken: 2.376s
# Task 1, num run 0, pop size 100, num ls 0, time taken: 1.288s
# Task 1, num run 0, pop size 100, num ls 10, time taken: 1.860s
# Task 1, num run 0, pop size 200, num ls 0, time taken: 3.288s
# Task 1, num run 0, pop size 200, num ls 10, time taken: 4.627s
# Task 1, num run 1, pop size 100, num ls 0, time taken: 1.450s
# Task 1, num run 1, pop size 100, num ls 10, time taken: 2.016s
# Task 1, num run 1, pop size 200, num ls 0, time taken: 2.716s
# Task 1, num run 1, pop size 200, num ls 10, time taken: 3.869s
# Task 1, num run 2, pop size 100, num ls 0, time taken: 1.225s
# Task 1, num run 2, pop size 100, num ls 10, time taken: 2.187s
# Task 1, num run 2, pop size 200, num ls 0, time taken: 2.645s
# Task 1, num run 2, pop size 200, num ls 10, time taken: 3.874s
# Task 1, num run 3, pop size 100, num ls 0, time taken: 1.067s
# Task 1, num run 3, pop size 100, num ls 10, time taken: 1.876s
# Task 1, num run 3, pop size 200, num ls 0, time taken: 2.752s
# Task 1, num run 3, pop size 200, num ls 10, time taken: 3.872s
# Task 1, num run 4, pop size 100, num ls 0, time taken: 1.307s
# Task 1, num run 4, pop size 100, num ls 10, time taken: 2.239s
# Task 1, num run 4, pop size 200, num ls 0, time taken: 2.715s
# Task 1, num run 4, pop size 200, num ls 10, time taken: 4.372s
# Task 1, num run 5, pop size 100, num ls 0, time taken: 1.004s
# Task 1, num run 5, pop size 100, num ls 10, time taken: 2.281s
# Task 1, num run 5, pop size 200, num ls 0, time taken: 2.641s
# Task 1, num run 5, pop size 200, num ls 10, time taken: 3.210s
# Task 1, num run 6, pop size 100, num ls 0, time taken: 1.146s
# Task 1, num run 6, pop size 100, num ls 10, time taken: 2.069s
# Task 1, num run 6, pop size 200, num ls 0, time taken: 3.185s
# Task 1, num run 6, pop size 200, num ls 10, time taken: 1.540s
# Task 1, num run 7, pop size 100, num ls 0, time taken: 1.150s
# Task 1, num run 7, pop size 100, num ls 10, time taken: 1.927s
# Task 1, num run 7, pop size 200, num ls 0, time taken: 3.131s
# Task 1, num run 7, pop size 200, num ls 10, time taken: 3.874s
# Task 1, num run 8, pop size 100, num ls 0, time taken: 1.064s
# Task 1, num run 8, pop size 100, num ls 10, time taken: 2.459s
# Task 1, num run 8, pop size 200, num ls 0, time taken: 2.470s
# Task 1, num run 8, pop size 200, num ls 10, time taken: 4.035s
# Task 1, num run 9, pop size 100, num ls 0, time taken: 1.082s
# Task 1, num run 9, pop size 100, num ls 10, time taken: 1.897s
# Task 1, num run 9, pop size 200, num ls 0, time taken: 2.697s
# Task 1, num run 9, pop size 200, num ls 10, time taken: 4.017s
# Task 2, num run 0, pop size 100, num ls 0, time taken: 0.727s
# Task 2, num run 0, pop size 100, num ls 10, time taken: 1.805s
# Task 2, num run 0, pop size 200, num ls 0, time taken: 2.732s
# Task 2, num run 0, pop size 200, num ls 10, time taken: 2.791s
# Task 2, num run 1, pop size 100, num ls 0, time taken: 1.738s
# Task 2, num run 1, pop size 100, num ls 10, time taken: 1.910s
# Task 2, num run 1, pop size 200, num ls 0, time taken: 2.303s
# Task 2, num run 1, pop size 200, num ls 10, time taken: 2.614s
# Task 2, num run 2, pop size 100, num ls 0, time taken: 0.794s
# Task 2, num run 2, pop size 100, num ls 10, time taken: 1.734s
# Task 2, num run 2, pop size 200, num ls 0, time taken: 2.090s
# Task 2, num run 2, pop size 200, num ls 10, time taken: 2.529s
# Task 2, num run 3, pop size 100, num ls 0, time taken: 1.060s
# Task 2, num run 3, pop size 100, num ls 10, time taken: 1.742s
# Task 2, num run 3, pop size 200, num ls 0, time taken: 1.999s
# Task 2, num run 3, pop size 200, num ls 10, time taken: 2.547s
# Task 2, num run 4, pop size 100, num ls 0, time taken: 0.867s
# Task 2, num run 4, pop size 100, num ls 10, time taken: 1.962s
# Task 2, num run 4, pop size 200, num ls 0, time taken: 1.979s
# Task 2, num run 4, pop size 200, num ls 10, time taken: 3.158s
# Task 2, num run 5, pop size 100, num ls 0, time taken: 1.186s
# Task 2, num run 5, pop size 100, num ls 10, time taken: 1.788s
# Task 2, num run 5, pop size 200, num ls 0, time taken: 2.090s
# Task 2, num run 5, pop size 200, num ls 10, time taken: 3.190s
# Task 2, num run 6, pop size 100, num ls 0, time taken: 1.067s
# Task 2, num run 6, pop size 100, num ls 10, time taken: 1.703s
# Task 2, num run 6, pop size 200, num ls 0, time taken: 2.405s
# Task 2, num run 6, pop size 200, num ls 10, time taken: 3.228s
# Task 2, num run 7, pop size 100, num ls 0, time taken: 1.036s
# Task 2, num run 7, pop size 100, num ls 10, time taken: 2.009s
# Task 2, num run 7, pop size 200, num ls 0, time taken: 2.669s
# Task 2, num run 7, pop size 200, num ls 10, time taken: 2.535s
# Task 2, num run 8, pop size 100, num ls 0, time taken: 0.995s
# Task 2, num run 8, pop size 100, num ls 10, time taken: 1.635s
# Task 2, num run 8, pop size 200, num ls 0, time taken: 1.989s
# Task 2, num run 8, pop size 200, num ls 10, time taken: 3.370s
# Task 2, num run 9, pop size 100, num ls 0, time taken: 1.005s
# Task 2, num run 9, pop size 100, num ls 10, time taken: 1.694s
# Task 2, num run 9, pop size 200, num ls 0, time taken: 2.167s
# Task 2, num run 9, pop size 200, num ls 10, time taken: 2.820s
# Task 3, num run 0, pop size 100, num ls 0, time taken: 1.087s
# Task 3, num run 0, pop size 100, num ls 10, time taken: 1.693s
# Task 3, num run 0, pop size 200, num ls 0, time taken: 2.190s
# Task 3, num run 0, pop size 200, num ls 10, time taken: 2.553s
# Task 3, num run 1, pop size 100, num ls 0, time taken: 1.119s
# Task 3, num run 1, pop size 100, num ls 10, time taken: 1.403s
# Task 3, num run 1, pop size 200, num ls 0, time taken: 2.262s
# Task 3, num run 1, pop size 200, num ls 10, time taken: 2.358s
# Task 3, num run 2, pop size 100, num ls 0, time taken: 0.915s
# Task 3, num run 2, pop size 100, num ls 10, time taken: 1.498s
# Task 3, num run 2, pop size 200, num ls 0, time taken: 1.818s
# Task 3, num run 2, pop size 200, num ls 10, time taken: 2.699s
# Task 3, num run 3, pop size 100, num ls 0, time taken: 1.098s
# Task 3, num run 3, pop size 100, num ls 10, time taken: 1.438s
# Task 3, num run 3, pop size 200, num ls 0, time taken: 2.330s
# Task 3, num run 3, pop size 200, num ls 10, time taken: 2.577s
# Task 3, num run 4, pop size 100, num ls 0, time taken: 1.301s
# Task 3, num run 4, pop size 100, num ls 10, time taken: 1.819s
# Task 3, num run 4, pop size 200, num ls 0, time taken: 2.194s
# Task 3, num run 4, pop size 200, num ls 10, time taken: 2.628s
# Task 3, num run 5, pop size 100, num ls 0, time taken: 0.985s
# Task 3, num run 5, pop size 100, num ls 10, time taken: 1.467s
# Task 3, num run 5, pop size 200, num ls 0, time taken: 1.631s
# Task 3, num run 5, pop size 200, num ls 10, time taken: 2.574s
# Task 3, num run 6, pop size 100, num ls 0, time taken: 0.904s
# Task 3, num run 6, pop size 100, num ls 10, time taken: 1.682s
# Task 3, num run 6, pop size 200, num ls 0, time taken: 2.036s
# Task 3, num run 6, pop size 200, num ls 10, time taken: 2.181s
# Task 3, num run 7, pop size 100, num ls 0, time taken: 1.049s
# Task 3, num run 7, pop size 100, num ls 10, time taken: 1.700s
# Task 3, num run 7, pop size 200, num ls 0, time taken: 1.918s
# Task 3, num run 7, pop size 200, num ls 10, time taken: 2.571s
# Task 3, num run 8, pop size 100, num ls 0, time taken: 1.102s
# Task 3, num run 8, pop size 100, num ls 10, time taken: 1.359s
# Task 3, num run 8, pop size 200, num ls 0, time taken: 1.768s
# Task 3, num run 8, pop size 200, num ls 10, time taken: 2.577s
# Task 3, num run 9, pop size 100, num ls 0, time taken: 0.934s
# Task 3, num run 9, pop size 100, num ls 10, time taken: 1.572s
# Task 3, num run 9, pop size 200, num ls 0, time taken: 1.635s
# Task 3, num run 9, pop size 200, num ls 10, time taken: 2.427s
# Task 4, num run 0, pop size 100, num ls 0, time taken: 1.252s
# Task 4, num run 0, pop size 100, num ls 10, time taken: 1.895s
# Task 4, num run 0, pop size 200, num ls 0, time taken: 2.383s
# Task 4, num run 0, pop size 200, num ls 10, time taken: 4.040s
# Task 4, num run 1, pop size 100, num ls 0, time taken: 1.141s
# Task 4, num run 1, pop size 100, num ls 10, time taken: 1.470s
# Task 4, num run 1, pop size 200, num ls 0, time taken: 2.112s
# Task 4, num run 1, pop size 200, num ls 10, time taken: 3.182s
# Task 4, num run 2, pop size 100, num ls 0, time taken: 1.153s
# Task 4, num run 2, pop size 100, num ls 10, time taken: 2.145s
# Task 4, num run 2, pop size 200, num ls 0, time taken: 2.330s
# Task 4, num run 2, pop size 200, num ls 10, time taken: 3.244s
# Task 4, num run 3, pop size 100, num ls 0, time taken: 1.068s
# Task 4, num run 3, pop size 100, num ls 10, time taken: 1.942s
# Task 4, num run 3, pop size 200, num ls 0, time taken: 2.191s
# Task 4, num run 3, pop size 200, num ls 10, time taken: 2.844s
# Task 4, num run 4, pop size 100, num ls 0, time taken: 0.984s
# Task 4, num run 4, pop size 100, num ls 10, time taken: 1.472s
# Task 4, num run 4, pop size 200, num ls 0, time taken: 2.720s
# Task 4, num run 4, pop size 200, num ls 10, time taken: 3.391s
# Task 4, num run 5, pop size 100, num ls 0, time taken: 1.045s
# Task 4, num run 5, pop size 100, num ls 10, time taken: 1.863s
# Task 4, num run 5, pop size 200, num ls 0, time taken: 2.358s
# Task 4, num run 5, pop size 200, num ls 10, time taken: 3.509s
# Task 4, num run 6, pop size 100, num ls 0, time taken: 1.111s
# Task 4, num run 6, pop size 100, num ls 10, time taken: 1.721s
# Task 4, num run 6, pop size 200, num ls 0, time taken: 2.551s
# Task 4, num run 6, pop size 200, num ls 10, time taken: 3.358s
# Task 4, num run 7, pop size 100, num ls 0, time taken: 1.252s
# Task 4, num run 7, pop size 100, num ls 10, time taken: 1.636s
# Task 4, num run 7, pop size 200, num ls 0, time taken: 1.995s
# Task 4, num run 7, pop size 200, num ls 10, time taken: 3.418s
# Task 4, num run 8, pop size 100, num ls 0, time taken: 1.068s
# Task 4, num run 8, pop size 100, num ls 10, time taken: 1.563s
# Task 4, num run 8, pop size 200, num ls 0, time taken: 2.186s
# Task 4, num run 8, pop size 200, num ls 10, time taken: 2.164s
# Task 4, num run 9, pop size 100, num ls 0, time taken: 1.018s
# Task 4, num run 9, pop size 100, num ls 10, time taken: 1.583s
# Task 4, num run 9, pop size 200, num ls 0, time taken: 2.542s
# Task 4, num run 9, pop size 200, num ls 10, time taken: 1.383s

# %% [markdown]
# ### Medium

# %% [markdown]
# #### Two Cut Crossover

# %%
for task_id in range(5):
    run_task_twocut("medium", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
# Out:
# Task 0, num run 0, pop size 100, num ls 0, time taken: 2.969s
# Task 0, num run 0, pop size 100, num ls 10, time taken: 9.197s
# Task 0, num run 0, pop size 200, num ls 0, time taken: 11.394s
# Task 0, num run 0, pop size 200, num ls 10, time taken: 14.885s
# Task 0, num run 1, pop size 100, num ls 0, time taken: 5.575s
# Task 0, num run 1, pop size 100, num ls 10, time taken: 8.666s
# Task 0, num run 1, pop size 200, num ls 0, time taken: 10.763s
# Task 0, num run 1, pop size 200, num ls 10, time taken: 16.230s
# Task 0, num run 2, pop size 100, num ls 0, time taken: 5.645s
# Task 0, num run 2, pop size 100, num ls 10, time taken: 9.155s
# Task 0, num run 2, pop size 200, num ls 0, time taken: 12.660s
# Task 0, num run 2, pop size 200, num ls 10, time taken: 16.293s
# Task 0, num run 3, pop size 100, num ls 0, time taken: 6.134s
# Task 0, num run 3, pop size 100, num ls 10, time taken: 7.791s
# Task 0, num run 3, pop size 200, num ls 0, time taken: 13.200s
# Task 0, num run 3, pop size 200, num ls 10, time taken: 18.015s
# Task 0, num run 4, pop size 100, num ls 0, time taken: 6.125s
# Task 0, num run 4, pop size 100, num ls 10, time taken: 10.625s
# Task 0, num run 4, pop size 200, num ls 0, time taken: 12.519s
# Task 0, num run 4, pop size 200, num ls 10, time taken: 16.190s
# Task 0, num run 5, pop size 100, num ls 0, time taken: 5.326s
# Task 0, num run 5, pop size 100, num ls 10, time taken: 6.696s
# Task 0, num run 5, pop size 200, num ls 0, time taken: 13.342s
# Task 0, num run 5, pop size 200, num ls 10, time taken: 17.114s
# Task 0, num run 6, pop size 100, num ls 0, time taken: 5.740s
# Task 0, num run 6, pop size 100, num ls 10, time taken: 10.259s
# Task 0, num run 6, pop size 200, num ls 0, time taken: 14.115s
# Task 0, num run 6, pop size 200, num ls 10, time taken: 20.321s
# Task 0, num run 7, pop size 100, num ls 0, time taken: 6.825s
# Task 0, num run 7, pop size 100, num ls 10, time taken: 10.123s
# Task 0, num run 7, pop size 200, num ls 0, time taken: 13.089s
# Task 0, num run 7, pop size 200, num ls 10, time taken: 20.142s
# Task 0, num run 8, pop size 100, num ls 0, time taken: 6.132s
# Task 0, num run 8, pop size 100, num ls 10, time taken: 9.972s
# Task 0, num run 8, pop size 200, num ls 0, time taken: 14.043s
# Task 0, num run 8, pop size 200, num ls 10, time taken: 18.581s
# Task 0, num run 9, pop size 100, num ls 0, time taken: 7.205s
# Task 0, num run 9, pop size 100, num ls 10, time taken: 10.770s
# Task 0, num run 9, pop size 200, num ls 0, time taken: 13.248s
# Task 0, num run 9, pop size 200, num ls 10, time taken: 16.708s
# Task 1, num run 0, pop size 100, num ls 0, time taken: 5.685s
# Task 1, num run 0, pop size 100, num ls 10, time taken: 9.915s
# Task 1, num run 0, pop size 200, num ls 0, time taken: 16.185s
# Task 1, num run 0, pop size 200, num ls 10, time taken: 17.361s
# Task 1, num run 1, pop size 100, num ls 0, time taken: 6.520s
# Task 1, num run 1, pop size 100, num ls 10, time taken: 10.258s
# Task 1, num run 1, pop size 200, num ls 0, time taken: 12.973s
# Task 1, num run 1, pop size 200, num ls 10, time taken: 18.264s
# Task 1, num run 2, pop size 100, num ls 0, time taken: 6.318s
# Task 1, num run 2, pop size 100, num ls 10, time taken: 8.789s
# Task 1, num run 2, pop size 200, num ls 0, time taken: 12.497s
# Task 1, num run 2, pop size 200, num ls 10, time taken: 17.802s
# Task 1, num run 3, pop size 100, num ls 0, time taken: 8.209s
# Task 1, num run 3, pop size 100, num ls 10, time taken: 9.855s
# Task 1, num run 3, pop size 200, num ls 0, time taken: 15.085s
# Task 1, num run 3, pop size 200, num ls 10, time taken: 17.706s
# Task 1, num run 4, pop size 100, num ls 0, time taken: 7.572s
# Task 1, num run 4, pop size 100, num ls 10, time taken: 12.154s
# Task 1, num run 4, pop size 200, num ls 0, time taken: 12.908s
# Task 1, num run 4, pop size 200, num ls 10, time taken: 18.059s
# Task 1, num run 5, pop size 100, num ls 0, time taken: 6.769s
# Task 1, num run 5, pop size 100, num ls 10, time taken: 10.097s
# Task 1, num run 5, pop size 200, num ls 0, time taken: 15.193s
# Task 1, num run 5, pop size 200, num ls 10, time taken: 18.914s
# Task 1, num run 6, pop size 100, num ls 0, time taken: 6.803s
# Task 1, num run 6, pop size 100, num ls 10, time taken: 12.629s
# Task 1, num run 6, pop size 200, num ls 0, time taken: 19.704s
# Task 1, num run 6, pop size 200, num ls 10, time taken: 15.867s
# Task 1, num run 7, pop size 100, num ls 0, time taken: 8.487s
# Task 1, num run 7, pop size 100, num ls 10, time taken: 11.458s
# Task 1, num run 7, pop size 200, num ls 0, time taken: 13.838s
# Task 1, num run 7, pop size 200, num ls 10, time taken: 17.577s
# Task 1, num run 8, pop size 100, num ls 0, time taken: 6.883s
# Task 1, num run 8, pop size 100, num ls 10, time taken: 11.745s
# Task 1, num run 8, pop size 200, num ls 0, time taken: 13.306s
# Task 1, num run 8, pop size 200, num ls 10, time taken: 17.677s
# Task 1, num run 9, pop size 100, num ls 0, time taken: 6.033s
# Task 1, num run 9, pop size 100, num ls 10, time taken: 11.260s
# Task 1, num run 9, pop size 200, num ls 0, time taken: 15.006s
# Task 1, num run 9, pop size 200, num ls 10, time taken: 17.016s
# Task 2, num run 0, pop size 100, num ls 0, time taken: 6.896s
# Task 2, num run 0, pop size 100, num ls 10, time taken: 9.577s
# Task 2, num run 0, pop size 200, num ls 0, time taken: 12.485s
# Task 2, num run 0, pop size 200, num ls 10, time taken: 17.160s
# Task 2, num run 1, pop size 100, num ls 0, time taken: 6.561s
# Task 2, num run 1, pop size 100, num ls 10, time taken: 10.543s
# Task 2, num run 1, pop size 200, num ls 0, time taken: 15.019s
# Task 2, num run 1, pop size 200, num ls 10, time taken: 17.912s
# Task 2, num run 2, pop size 100, num ls 0, time taken: 6.565s
# Task 2, num run 2, pop size 100, num ls 10, time taken: 11.654s
# Task 2, num run 2, pop size 200, num ls 0, time taken: 13.324s
# Task 2, num run 2, pop size 200, num ls 10, time taken: 19.271s
# Task 2, num run 3, pop size 100, num ls 0, time taken: 6.850s
# Task 2, num run 3, pop size 100, num ls 10, time taken: 9.579s
# Task 2, num run 3, pop size 200, num ls 0, time taken: 13.759s
# Task 2, num run 3, pop size 200, num ls 10, time taken: 18.933s
# Task 2, num run 4, pop size 100, num ls 0, time taken: 6.817s
# Task 2, num run 4, pop size 100, num ls 10, time taken: 10.505s
# Task 2, num run 4, pop size 200, num ls 0, time taken: 11.226s
# Task 2, num run 4, pop size 200, num ls 10, time taken: 15.868s
# Task 2, num run 5, pop size 100, num ls 0, time taken: 6.845s
# Task 2, num run 5, pop size 100, num ls 10, time taken: 9.761s
# Task 2, num run 5, pop size 200, num ls 0, time taken: 14.501s
# Task 2, num run 5, pop size 200, num ls 10, time taken: 17.782s
# Task 2, num run 6, pop size 100, num ls 0, time taken: 6.539s
# Task 2, num run 6, pop size 100, num ls 10, time taken: 9.481s
# Task 2, num run 6, pop size 200, num ls 0, time taken: 13.269s
# Task 2, num run 6, pop size 200, num ls 10, time taken: 16.004s
# Task 2, num run 7, pop size 100, num ls 0, time taken: 7.382s
# Task 2, num run 7, pop size 100, num ls 10, time taken: 10.898s
# Task 2, num run 7, pop size 200, num ls 0, time taken: 11.946s
# Task 2, num run 7, pop size 200, num ls 10, time taken: 31.988s
# Task 2, num run 8, pop size 100, num ls 0, time taken: 17.025s
# Task 2, num run 8, pop size 100, num ls 10, time taken: 23.188s
# Task 2, num run 8, pop size 200, num ls 0, time taken: 32.616s
# Task 2, num run 8, pop size 200, num ls 10, time taken: 39.295s
# Task 2, num run 9, pop size 100, num ls 0, time taken: 13.992s
# Task 2, num run 9, pop size 100, num ls 10, time taken: 23.237s
# Task 2, num run 9, pop size 200, num ls 0, time taken: 27.261s
# Task 2, num run 9, pop size 200, num ls 10, time taken: 39.564s
# Task 3, num run 0, pop size 100, num ls 0, time taken: 14.486s
# Task 3, num run 0, pop size 100, num ls 10, time taken: 22.776s
# Task 3, num run 0, pop size 200, num ls 0, time taken: 31.434s
# Task 3, num run 0, pop size 200, num ls 10, time taken: 38.612s
# Task 3, num run 1, pop size 100, num ls 0, time taken: 14.916s
# Task 3, num run 1, pop size 100, num ls 10, time taken: 24.452s
# Task 3, num run 1, pop size 200, num ls 0, time taken: 24.942s
# Task 3, num run 1, pop size 200, num ls 10, time taken: 42.397s
# Task 3, num run 2, pop size 100, num ls 0, time taken: 12.624s
# Task 3, num run 2, pop size 100, num ls 10, time taken: 22.099s
# Task 3, num run 2, pop size 200, num ls 0, time taken: 25.998s
# Task 3, num run 2, pop size 200, num ls 10, time taken: 36.793s
# Task 3, num run 3, pop size 100, num ls 0, time taken: 13.898s
# Task 3, num run 3, pop size 100, num ls 10, time taken: 24.012s
# Task 3, num run 3, pop size 200, num ls 0, time taken: 29.675s
# Task 3, num run 3, pop size 200, num ls 10, time taken: 41.717s
# Task 3, num run 4, pop size 100, num ls 0, time taken: 14.856s
# Task 3, num run 4, pop size 100, num ls 10, time taken: 27.115s
# Task 3, num run 4, pop size 200, num ls 0, time taken: 30.115s
# Task 3, num run 4, pop size 200, num ls 10, time taken: 41.907s
# Task 3, num run 5, pop size 100, num ls 0, time taken: 14.603s
# Task 3, num run 5, pop size 100, num ls 10, time taken: 26.220s
# Task 3, num run 5, pop size 200, num ls 0, time taken: 33.379s
# Task 3, num run 5, pop size 200, num ls 10, time taken: 39.457s
# Task 3, num run 6, pop size 100, num ls 0, time taken: 8.068s
# Task 3, num run 6, pop size 100, num ls 10, time taken: 9.690s
# Task 3, num run 6, pop size 200, num ls 0, time taken: 13.058s
# Task 3, num run 6, pop size 200, num ls 10, time taken: 18.789s
# Task 3, num run 7, pop size 100, num ls 0, time taken: 6.511s
# Task 3, num run 7, pop size 100, num ls 10, time taken: 10.446s
# Task 3, num run 7, pop size 200, num ls 0, time taken: 13.594s
# Task 3, num run 7, pop size 200, num ls 10, time taken: 16.630s
# Task 3, num run 8, pop size 100, num ls 0, time taken: 6.582s
# Task 3, num run 8, pop size 100, num ls 10, time taken: 9.141s
# Task 3, num run 8, pop size 200, num ls 0, time taken: 12.142s
# Task 3, num run 8, pop size 200, num ls 10, time taken: 17.154s
# Task 3, num run 9, pop size 100, num ls 0, time taken: 6.187s
# Task 3, num run 9, pop size 100, num ls 10, time taken: 10.402s
# Task 3, num run 9, pop size 200, num ls 0, time taken: 11.809s
# Task 3, num run 9, pop size 200, num ls 10, time taken: 16.862s
# Task 4, num run 0, pop size 100, num ls 0, time taken: 4.488s
# Task 4, num run 0, pop size 100, num ls 10, time taken: 14.123s
# Task 4, num run 0, pop size 200, num ls 0, time taken: 4.680s
# Task 4, num run 0, pop size 200, num ls 10, time taken: 28.748s
# Task 4, num run 1, pop size 100, num ls 0, time taken: 9.997s
# Task 4, num run 1, pop size 100, num ls 10, time taken: 15.558s
# Task 4, num run 1, pop size 200, num ls 0, time taken: 24.462s
# Task 4, num run 1, pop size 200, num ls 10, time taken: 23.116s
# Task 4, num run 2, pop size 100, num ls 0, time taken: 10.228s
# Task 4, num run 2, pop size 100, num ls 10, time taken: 14.569s
# Task 4, num run 2, pop size 200, num ls 0, time taken: 20.941s
# Task 4, num run 2, pop size 200, num ls 10, time taken: 35.079s
# Task 4, num run 3, pop size 100, num ls 0, time taken: 9.667s
# Task 4, num run 3, pop size 100, num ls 10, time taken: 17.077s
# Task 4, num run 3, pop size 200, num ls 0, time taken: 23.160s
# Task 4, num run 3, pop size 200, num ls 10, time taken: 28.345s
# Task 4, num run 4, pop size 100, num ls 0, time taken: 9.667s
# Task 4, num run 4, pop size 100, num ls 10, time taken: 16.269s
# Task 4, num run 4, pop size 200, num ls 0, time taken: 22.556s
# Task 4, num run 4, pop size 200, num ls 10, time taken: 30.883s
# Task 4, num run 5, pop size 100, num ls 0, time taken: 9.344s
# Task 4, num run 5, pop size 100, num ls 10, time taken: 20.423s
# Task 4, num run 5, pop size 200, num ls 0, time taken: 18.065s
# Task 4, num run 5, pop size 200, num ls 10, time taken: 15.842s
# Task 4, num run 6, pop size 100, num ls 0, time taken: 2.935s
# Task 4, num run 6, pop size 100, num ls 10, time taken: 14.064s
# Task 4, num run 6, pop size 200, num ls 0, time taken: 21.871s
# Task 4, num run 6, pop size 200, num ls 10, time taken: 29.839s
# Task 4, num run 7, pop size 100, num ls 0, time taken: 9.825s
# Task 4, num run 7, pop size 100, num ls 10, time taken: 16.487s
# Task 4, num run 7, pop size 200, num ls 0, time taken: 25.821s
# Task 4, num run 7, pop size 200, num ls 10, time taken: 32.481s
# Task 4, num run 8, pop size 100, num ls 0, time taken: 9.056s
# Task 4, num run 8, pop size 100, num ls 10, time taken: 17.955s
# Task 4, num run 8, pop size 200, num ls 0, time taken: 13.273s
# Task 4, num run 8, pop size 200, num ls 10, time taken: 27.030s
# Task 4, num run 9, pop size 100, num ls 0, time taken: 9.141s
# Task 4, num run 9, pop size 100, num ls 10, time taken: 13.649s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for task_id in range(5):
# ----> 2     run_task_twocut("medium", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
#
# Cell In[9], line 22, in run_task_twocut(task_type, task_id, num_run, pop_sizes, num_lss)
#      15 np.random.seed(counter)
#      17 model = Model(pop_size=pop_size,
#      18 		task=task,
#      19 		crossover=TwoCutCrossover(),
#      20 		mutation=InsertionMutation(),
#      21 		localsearch=SimpleLocalSearch())
# ---> 22 bfs, _ = model.fit(num_gen=1000,
#      23 				num_crossover=pop_size,
#      24 				num_mutation=int(pop_size * 0.05),
#      25 				num_ls=num_ls,
#      26 				monitor=False)
#      27 bfs = np.array(bfs)
#      28 df = pd.DataFrame(bfs.T)
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\GA.py:47, in Model.fit(self, num_gen, num_crossover, num_mutation, num_ls, monitor, monitor_rate)
#      45 pa = self.get_random_indi()
#      46 pb = self.get_random_indi()
# ---> 47 oc = self.crossover(pa, pb) #crossover offspring
#      48 while oc.check_valid() == False:
#      49     oc.fix()
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\crossover\twocut.py:32, in TwoCutCrossover.__call__(self, pa, pb)
#      31 def __call__(self, pa:Individual, pb:Individual) -> Individual:
# ---> 32     return self.crossover(pa, pb)
#
# File c:\Users\madmo\Workspace\project2_supply_chain_optimize\crossover\twocut.py:14, in TwoCutCrossover.crossover(self, pa, pb)
#      11 gene_o = gene_a.copy()
#      13 deli_types_o = pa.deli_types.copy()
# ---> 14 rnd = np.random.uniform(size=deli_types_o.shape)
#      15 deli_types_o[rnd < 0.5] = pb.deli_types[rnd < 0.5]
#      17 fi_cut : int = np.random.randint(0, pa.task.num_customers) * 3
#
# KeyboardInterrupt:

# %% [markdown]
# #### Combinatorial Crossover

# %%
for task_id in range(5):
    run_task_comb("medium", task_id=task_id, num_run=10, pop_sizes=[100, 200], num_lss=[0, 10])
# Out:
# Task 0, num run 0, pop size 100, num ls 0, time taken: 5.641s
# Task 0, num run 0, pop size 100, num ls 10, time taken: 10.246s
# Task 0, num run 0, pop size 200, num ls 0, time taken: 13.361s
# Task 0, num run 0, pop size 200, num ls 10, time taken: 18.215s
# Task 0, num run 1, pop size 100, num ls 0, time taken: 6.850s
# Task 0, num run 1, pop size 100, num ls 10, time taken: 9.657s
# Task 0, num run 1, pop size 200, num ls 0, time taken: 15.273s
# Task 0, num run 1, pop size 200, num ls 10, time taken: 21.114s
# Task 0, num run 2, pop size 100, num ls 0, time taken: 7.933s
# Task 0, num run 2, pop size 100, num ls 10, time taken: 14.510s
# Task 0, num run 2, pop size 200, num ls 0, time taken: 15.689s
# Task 0, num run 2, pop size 200, num ls 10, time taken: 17.427s
# Task 0, num run 3, pop size 100, num ls 0, time taken: 7.661s
# Task 0, num run 3, pop size 100, num ls 10, time taken: 10.237s
# Task 0, num run 3, pop size 200, num ls 0, time taken: 13.500s
# Task 0, num run 3, pop size 200, num ls 10, time taken: 16.113s
# Task 0, num run 4, pop size 100, num ls 0, time taken: 6.058s
# Task 0, num run 4, pop size 100, num ls 10, time taken: 9.396s
# Task 0, num run 4, pop size 200, num ls 0, time taken: 13.112s
# Task 0, num run 4, pop size 200, num ls 10, time taken: 15.982s
# Task 0, num run 5, pop size 100, num ls 0, time taken: 6.675s
# Task 0, num run 5, pop size 100, num ls 10, time taken: 11.343s
# Task 0, num run 5, pop size 200, num ls 0, time taken: 13.729s
# Task 0, num run 5, pop size 200, num ls 10, time taken: 16.495s
# Task 0, num run 6, pop size 100, num ls 0, time taken: 6.611s
# Task 0, num run 6, pop size 100, num ls 10, time taken: 10.360s
# Task 0, num run 6, pop size 200, num ls 0, time taken: 13.409s
# Task 0, num run 6, pop size 200, num ls 10, time taken: 18.052s
# Task 0, num run 7, pop size 100, num ls 0, time taken: 6.536s
# Task 0, num run 7, pop size 100, num ls 10, time taken: 10.381s
# Task 0, num run 7, pop size 200, num ls 0, time taken: 14.225s
# Task 0, num run 7, pop size 200, num ls 10, time taken: 19.036s
# Task 0, num run 8, pop size 100, num ls 0, time taken: 6.164s
# Task 0, num run 8, pop size 100, num ls 10, time taken: 9.352s
# Task 0, num run 8, pop size 200, num ls 0, time taken: 13.080s
# Task 0, num run 8, pop size 200, num ls 10, time taken: 17.311s
# Task 0, num run 9, pop size 100, num ls 0, time taken: 6.918s
# Task 0, num run 9, pop size 100, num ls 10, time taken: 10.118s
# Task 0, num run 9, pop size 200, num ls 0, time taken: 13.821s
# Task 0, num run 9, pop size 200, num ls 10, time taken: 19.551s
# Task 1, num run 0, pop size 100, num ls 0, time taken: 7.159s
# Task 1, num run 0, pop size 100, num ls 10, time taken: 10.262s
# Task 1, num run 0, pop size 200, num ls 0, time taken: 12.756s
# Task 1, num run 0, pop size 200, num ls 10, time taken: 18.308s
# Task 1, num run 1, pop size 100, num ls 0, time taken: 6.900s
# Task 1, num run 1, pop size 100, num ls 10, time taken: 11.071s
# Task 1, num run 1, pop size 200, num ls 0, time taken: 12.894s
# Task 1, num run 1, pop size 200, num ls 10, time taken: 15.834s
# Task 1, num run 2, pop size 100, num ls 0, time taken: 7.377s
# Task 1, num run 2, pop size 100, num ls 10, time taken: 9.895s
# Task 1, num run 2, pop size 200, num ls 0, time taken: 13.014s
# Task 1, num run 2, pop size 200, num ls 10, time taken: 15.303s
# Task 1, num run 3, pop size 100, num ls 0, time taken: 6.541s
# Task 1, num run 3, pop size 100, num ls 10, time taken: 10.273s
# Task 1, num run 3, pop size 200, num ls 0, time taken: 12.008s
# Task 1, num run 3, pop size 200, num ls 10, time taken: 19.159s
# Task 1, num run 4, pop size 100, num ls 0, time taken: 5.833s
# Task 1, num run 4, pop size 100, num ls 10, time taken: 9.974s
# Task 1, num run 4, pop size 200, num ls 0, time taken: 13.422s
# Task 1, num run 4, pop size 200, num ls 10, time taken: 18.868s
# Task 1, num run 5, pop size 100, num ls 0, time taken: 6.317s
# Task 1, num run 5, pop size 100, num ls 10, time taken: 10.219s
# Task 1, num run 5, pop size 200, num ls 0, time taken: 13.044s
# Task 1, num run 5, pop size 200, num ls 10, time taken: 16.392s
# Task 1, num run 6, pop size 100, num ls 0, time taken: 6.697s
# Task 1, num run 6, pop size 100, num ls 10, time taken: 9.845s
# Task 1, num run 6, pop size 200, num ls 0, time taken: 13.225s
# Task 1, num run 6, pop size 200, num ls 10, time taken: 19.161s
# Task 1, num run 7, pop size 100, num ls 0, time taken: 7.251s
# Task 1, num run 7, pop size 100, num ls 10, time taken: 11.275s
# Task 1, num run 7, pop size 200, num ls 0, time taken: 14.129s
# Task 1, num run 7, pop size 200, num ls 10, time taken: 18.076s
# Task 1, num run 8, pop size 100, num ls 0, time taken: 5.809s
# Task 1, num run 8, pop size 100, num ls 10, time taken: 10.685s
# Task 1, num run 8, pop size 200, num ls 0, time taken: 12.282s
# Task 1, num run 8, pop size 200, num ls 10, time taken: 18.503s
# Task 1, num run 9, pop size 100, num ls 0, time taken: 6.579s
# Task 1, num run 9, pop size 100, num ls 10, time taken: 10.113s
# Task 1, num run 9, pop size 200, num ls 0, time taken: 13.956s
# Task 1, num run 9, pop size 200, num ls 10, time taken: 18.604s
# Task 2, num run 0, pop size 100, num ls 0, time taken: 6.045s
# Task 2, num run 0, pop size 100, num ls 10, time taken: 11.062s
# Task 2, num run 0, pop size 200, num ls 0, time taken: 13.385s
# Task 2, num run 0, pop size 200, num ls 10, time taken: 15.543s
# Task 2, num run 1, pop size 100, num ls 0, time taken: 6.052s
# Task 2, num run 1, pop size 100, num ls 10, time taken: 9.249s
# Task 2, num run 1, pop size 200, num ls 0, time taken: 12.441s
# Task 2, num run 1, pop size 200, num ls 10, time taken: 16.017s
# Task 2, num run 2, pop size 100, num ls 0, time taken: 5.780s
# Task 2, num run 2, pop size 100, num ls 10, time taken: 9.281s
# Task 2, num run 2, pop size 200, num ls 0, time taken: 12.161s
# Task 2, num run 2, pop size 200, num ls 10, time taken: 20.129s
# Task 2, num run 3, pop size 100, num ls 0, time taken: 6.374s
# Task 2, num run 3, pop size 100, num ls 10, time taken: 10.062s
# Task 2, num run 3, pop size 200, num ls 0, time taken: 13.932s
# Task 2, num run 3, pop size 200, num ls 10, time taken: 17.625s
# Task 2, num run 4, pop size 100, num ls 0, time taken: 6.363s
# Task 2, num run 4, pop size 100, num ls 10, time taken: 11.942s
# Task 2, num run 4, pop size 200, num ls 0, time taken: 12.856s
# Task 2, num run 4, pop size 200, num ls 10, time taken: 19.831s
# Task 2, num run 5, pop size 100, num ls 0, time taken: 7.003s
# Task 2, num run 5, pop size 100, num ls 10, time taken: 10.812s
# Task 2, num run 5, pop size 200, num ls 0, time taken: 14.390s
# Task 2, num run 5, pop size 200, num ls 10, time taken: 18.951s
# Task 2, num run 6, pop size 100, num ls 0, time taken: 6.429s
# Task 2, num run 6, pop size 100, num ls 10, time taken: 10.196s
# Task 2, num run 6, pop size 200, num ls 0, time taken: 14.354s
# Task 2, num run 6, pop size 200, num ls 10, time taken: 26.261s
# Task 2, num run 7, pop size 100, num ls 0, time taken: 7.686s
# Task 2, num run 7, pop size 100, num ls 10, time taken: 9.852s
# Task 2, num run 7, pop size 200, num ls 0, time taken: 13.425s
# Task 2, num run 7, pop size 200, num ls 10, time taken: 17.808s
# Task 2, num run 8, pop size 100, num ls 0, time taken: 6.331s
# Task 2, num run 8, pop size 100, num ls 10, time taken: 10.328s
# Task 2, num run 8, pop size 200, num ls 0, time taken: 13.365s
# Task 2, num run 8, pop size 200, num ls 10, time taken: 16.506s
# Task 2, num run 9, pop size 100, num ls 0, time taken: 6.307s
# Task 2, num run 9, pop size 100, num ls 10, time taken: 12.417s
# Task 2, num run 9, pop size 200, num ls 0, time taken: 12.659s
# Task 2, num run 9, pop size 200, num ls 10, time taken: 14.836s
# Task 3, num run 0, pop size 100, num ls 0, time taken: 6.504s
# Task 3, num run 0, pop size 100, num ls 10, time taken: 9.275s
# Task 3, num run 0, pop size 200, num ls 0, time taken: 12.337s
# Task 3, num run 0, pop size 200, num ls 10, time taken: 15.596s
# Task 3, num run 1, pop size 100, num ls 0, time taken: 5.953s
# Task 3, num run 1, pop size 100, num ls 10, time taken: 10.554s
# Task 3, num run 1, pop size 200, num ls 0, time taken: 11.810s
# Task 3, num run 1, pop size 200, num ls 10, time taken: 16.530s
# Task 3, num run 2, pop size 100, num ls 0, time taken: 5.721s
# Task 3, num run 2, pop size 100, num ls 10, time taken: 10.079s
# Task 3, num run 2, pop size 200, num ls 0, time taken: 15.410s
# Task 3, num run 2, pop size 200, num ls 10, time taken: 18.340s
# Task 3, num run 3, pop size 100, num ls 0, time taken: 7.148s
# Task 3, num run 3, pop size 100, num ls 10, time taken: 11.352s
# Task 3, num run 3, pop size 200, num ls 0, time taken: 12.278s
# Task 3, num run 3, pop size 200, num ls 10, time taken: 16.528s
# Task 3, num run 4, pop size 100, num ls 0, time taken: 6.097s
# Task 3, num run 4, pop size 100, num ls 10, time taken: 10.718s
# Task 3, num run 4, pop size 200, num ls 0, time taken: 12.808s
# Task 3, num run 4, pop size 200, num ls 10, time taken: 15.602s
# Task 3, num run 5, pop size 100, num ls 0, time taken: 6.936s
# Task 3, num run 5, pop size 100, num ls 10, time taken: 12.411s
# Task 3, num run 5, pop size 200, num ls 0, time taken: 15.119s
# Task 3, num run 5, pop size 200, num ls 10, time taken: 19.967s
# Task 3, num run 6, pop size 100, num ls 0, time taken: 8.047s
# Task 3, num run 6, pop size 100, num ls 10, time taken: 11.399s
# Task 3, num run 6, pop size 200, num ls 0, time taken: 12.066s
# Task 3, num run 6, pop size 200, num ls 10, time taken: 15.418s
# Task 3, num run 7, pop size 100, num ls 0, time taken: 5.902s
# Task 3, num run 7, pop size 100, num ls 10, time taken: 11.044s
# Task 3, num run 7, pop size 200, num ls 0, time taken: 11.942s
# Task 3, num run 7, pop size 200, num ls 10, time taken: 17.343s
# Task 3, num run 8, pop size 100, num ls 0, time taken: 6.785s
# Task 3, num run 8, pop size 100, num ls 10, time taken: 11.842s
# Task 3, num run 8, pop size 200, num ls 0, time taken: 11.405s
# Task 3, num run 8, pop size 200, num ls 10, time taken: 15.950s
# Task 3, num run 9, pop size 100, num ls 0, time taken: 5.950s
# Task 3, num run 9, pop size 100, num ls 10, time taken: 9.952s
# Task 3, num run 9, pop size 200, num ls 0, time taken: 11.925s
# Task 3, num run 9, pop size 200, num ls 10, time taken: 16.420s
# Task 4, num run 0, pop size 100, num ls 0, time taken: 9.959s
# Task 4, num run 0, pop size 100, num ls 10, time taken: 15.556s
# Task 4, num run 0, pop size 200, num ls 0, time taken: 20.416s
# Task 4, num run 0, pop size 200, num ls 10, time taken: 32.147s
# Task 4, num run 1, pop size 100, num ls 0, time taken: 9.104s
# Task 4, num run 1, pop size 100, num ls 10, time taken: 16.641s
# Task 4, num run 1, pop size 200, num ls 0, time taken: 23.502s
# Task 4, num run 1, pop size 200, num ls 10, time taken: 32.860s
# Task 4, num run 2, pop size 100, num ls 0, time taken: 10.380s
# Task 4, num run 2, pop size 100, num ls 10, time taken: 16.210s
# Task 4, num run 2, pop size 200, num ls 0, time taken: 20.064s
# Task 4, num run 2, pop size 200, num ls 10, time taken: 29.703s
# Task 4, num run 3, pop size 100, num ls 0, time taken: 10.130s
# Task 4, num run 3, pop size 100, num ls 10, time taken: 20.323s
# Task 4, num run 3, pop size 200, num ls 0, time taken: 24.498s
# Task 4, num run 3, pop size 200, num ls 10, time taken: 29.752s
# Task 4, num run 4, pop size 100, num ls 0, time taken: 9.080s
# Task 4, num run 4, pop size 100, num ls 10, time taken: 16.164s
# Task 4, num run 4, pop size 200, num ls 0, time taken: 19.228s
# Task 4, num run 4, pop size 200, num ls 10, time taken: 32.407s
# Task 4, num run 5, pop size 100, num ls 0, time taken: 10.419s
# Task 4, num run 5, pop size 100, num ls 10, time taken: 20.083s
# Task 4, num run 5, pop size 200, num ls 0, time taken: 21.379s
# Task 4, num run 5, pop size 200, num ls 10, time taken: 32.324s
# Task 4, num run 6, pop size 100, num ls 0, time taken: 8.954s
# Task 4, num run 6, pop size 100, num ls 10, time taken: 16.098s
# Task 4, num run 6, pop size 200, num ls 0, time taken: 16.999s
# Task 4, num run 6, pop size 200, num ls 10, time taken: 28.880s
# Task 4, num run 7, pop size 100, num ls 0, time taken: 10.106s
# Task 4, num run 7, pop size 100, num ls 10, time taken: 17.315s
# Task 4, num run 7, pop size 200, num ls 0, time taken: 19.027s
# Task 4, num run 7, pop size 200, num ls 10, time taken: 36.938s
# Task 4, num run 8, pop size 100, num ls 0, time taken: 9.167s
# Task 4, num run 8, pop size 100, num ls 10, time taken: 18.228s
# Task 4, num run 8, pop size 200, num ls 0, time taken: 17.414s
# Task 4, num run 8, pop size 200, num ls 10, time taken: 32.156s
# Task 4, num run 9, pop size 100, num ls 0, time taken: 10.142s
# Task 4, num run 9, pop size 100, num ls 10, time taken: 19.318s
# Task 4, num run 9, pop size 200, num ls 0, time taken: 23.737s
# Task 4, num run 9, pop size 200, num ls 10, time taken: 19.757s

# %% [markdown]
# ### Large

# %% [markdown]
# #### Two Cut Crossover

# %%
for task_id in range(5):
    run_task_twocut("large", task_id=task_id, num_run=5, pop_sizes=[100, 200], num_lss=[0, 5])
# Out:
# Task 0, num run 0, pop size 100, num ls 0, time taken: 99.199s
# Task 0, num run 0, pop size 100, num ls 5, time taken: 13.107s
# Task 0, num run 0, pop size 200, num ls 0, time taken: 83.766s
# Task 0, num run 0, pop size 200, num ls 5, time taken: 115.455s
# Task 0, num run 1, pop size 100, num ls 0, time taken: 33.649s
# Task 0, num run 1, pop size 100, num ls 5, time taken: 76.418s
# Task 0, num run 1, pop size 200, num ls 0, time taken: 374.852s
# Task 0, num run 1, pop size 200, num ls 5, time taken: 70.974s
# Task 0, num run 2, pop size 100, num ls 0, time taken: 91.529s
# Task 0, num run 2, pop size 100, num ls 5, time taken: 153.801s
# Task 0, num run 2, pop size 200, num ls 0, time taken: 170.245s
# Task 0, num run 2, pop size 200, num ls 5, time taken: 301.065s
# Task 0, num run 3, pop size 100, num ls 0, time taken: 35.927s
# Task 0, num run 3, pop size 100, num ls 5, time taken: 86.754s
# Task 0, num run 3, pop size 200, num ls 0, time taken: 109.056s
# Task 0, num run 3, pop size 200, num ls 5, time taken: 271.187s
# Task 0, num run 4, pop size 100, num ls 0, time taken: 83.571s
# Task 0, num run 4, pop size 100, num ls 5, time taken: 170.103s
# Task 0, num run 4, pop size 200, num ls 0, time taken: 127.310s
# Task 0, num run 4, pop size 200, num ls 5, time taken: 82.736s
# Task 1, num run 0, pop size 100, num ls 0, time taken: 32.232s
# Task 1, num run 0, pop size 100, num ls 5, time taken: 39.114s
# Task 1, num run 0, pop size 200, num ls 0, time taken: 63.837s
# Task 1, num run 0, pop size 200, num ls 5, time taken: 82.170s
# Task 1, num run 1, pop size 100, num ls 0, time taken: 32.441s
# Task 1, num run 1, pop size 100, num ls 5, time taken: 43.766s
# Task 1, num run 1, pop size 200, num ls 0, time taken: 65.686s
# Task 1, num run 1, pop size 200, num ls 5, time taken: 83.500s
# Task 1, num run 2, pop size 100, num ls 0, time taken: 32.752s
# Task 1, num run 2, pop size 100, num ls 5, time taken: 52.635s
# Task 1, num run 2, pop size 200, num ls 0, time taken: 68.282s
# Task 1, num run 2, pop size 200, num ls 5, time taken: 93.489s
# Task 1, num run 3, pop size 100, num ls 0, time taken: 28.339s
# Task 1, num run 3, pop size 100, num ls 5, time taken: 47.403s
# Task 1, num run 3, pop size 200, num ls 0, time taken: 69.859s
# Task 1, num run 3, pop size 200, num ls 5, time taken: 75.877s
# Task 1, num run 4, pop size 100, num ls 0, time taken: 29.758s
# Task 1, num run 4, pop size 100, num ls 5, time taken: 42.092s
# Task 1, num run 4, pop size 200, num ls 0, time taken: 60.460s
# Task 1, num run 4, pop size 200, num ls 5, time taken: 89.553s
# Task 2, num run 0, pop size 100, num ls 0, time taken: 34.101s
# Task 2, num run 0, pop size 100, num ls 5, time taken: 50.256s
# Task 2, num run 0, pop size 200, num ls 0, time taken: 65.571s
# Task 2, num run 0, pop size 200, num ls 5, time taken: 79.635s
# Task 2, num run 1, pop size 100, num ls 0, time taken: 33.851s
# Task 2, num run 1, pop size 100, num ls 5, time taken: 43.051s
# Task 2, num run 1, pop size 200, num ls 0, time taken: 73.044s
# Task 2, num run 1, pop size 200, num ls 5, time taken: 85.751s
# Task 2, num run 2, pop size 100, num ls 0, time taken: 28.951s
# Task 2, num run 2, pop size 100, num ls 5, time taken: 52.897s
# Task 2, num run 2, pop size 200, num ls 0, time taken: 70.640s
# Task 2, num run 2, pop size 200, num ls 5, time taken: 87.932s
# Task 2, num run 3, pop size 100, num ls 0, time taken: 29.377s
# Task 2, num run 3, pop size 100, num ls 5, time taken: 30.575s
# Task 2, num run 3, pop size 200, num ls 0, time taken: 63.053s
# Task 2, num run 3, pop size 200, num ls 5, time taken: 85.551s
# Task 2, num run 4, pop size 100, num ls 0, time taken: 27.166s
# Task 2, num run 4, pop size 100, num ls 5, time taken: 45.295s
# Task 2, num run 4, pop size 200, num ls 0, time taken: 73.185s
# Task 2, num run 4, pop size 200, num ls 5, time taken: 89.290s
# Task 3, num run 0, pop size 100, num ls 0, time taken: 29.683s
# Task 3, num run 0, pop size 100, num ls 5, time taken: 45.941s
# Task 3, num run 0, pop size 200, num ls 0, time taken: 65.918s
# Task 3, num run 0, pop size 200, num ls 5, time taken: 76.436s
# Task 3, num run 1, pop size 100, num ls 0, time taken: 27.433s
# Task 3, num run 1, pop size 100, num ls 5, time taken: 42.235s
# Task 3, num run 1, pop size 200, num ls 0, time taken: 66.059s
# Task 3, num run 1, pop size 200, num ls 5, time taken: 10.918s
# Task 3, num run 2, pop size 100, num ls 0, time taken: 27.266s
# Task 3, num run 2, pop size 100, num ls 5, time taken: 44.793s
# Task 3, num run 2, pop size 200, num ls 0, time taken: 7013.884s
# Task 3, num run 2, pop size 200, num ls 5, time taken: 23183.411s
# Task 3, num run 3, pop size 100, num ls 0, time taken: 27.295s
# Task 3, num run 3, pop size 100, num ls 5, time taken: 42.057s
# Task 3, num run 3, pop size 200, num ls 0, time taken: 68.793s
# Task 3, num run 3, pop size 200, num ls 5, time taken: 107.246s
# Task 3, num run 4, pop size 100, num ls 0, time taken: 43.574s
# Task 3, num run 4, pop size 100, num ls 5, time taken: 47.850s
# Task 3, num run 4, pop size 200, num ls 0, time taken: 60.324s
# Task 3, num run 4, pop size 200, num ls 5, time taken: 83.691s
# Task 4, num run 0, pop size 100, num ls 0, time taken: 36.988s
# Task 4, num run 0, pop size 100, num ls 5, time taken: 75.361s
# Task 4, num run 0, pop size 200, num ls 0, time taken: 121.014s
# Task 4, num run 0, pop size 200, num ls 5, time taken: 120.462s
# Task 4, num run 1, pop size 100, num ls 0, time taken: 47.672s
# Task 4, num run 1, pop size 100, num ls 5, time taken: 49.849s
# Task 4, num run 1, pop size 200, num ls 0, time taken: 103.367s
# Task 4, num run 1, pop size 200, num ls 5, time taken: 121.231s
# Task 4, num run 2, pop size 100, num ls 0, time taken: 43.760s
# Task 4, num run 2, pop size 100, num ls 5, time taken: 56.664s
# Task 4, num run 2, pop size 200, num ls 0, time taken: 88.661s
# Task 4, num run 2, pop size 200, num ls 5, time taken: 111.504s
# Task 4, num run 3, pop size 100, num ls 0, time taken: 41.080s
# Task 4, num run 3, pop size 100, num ls 5, time taken: 66.527s
# Task 4, num run 3, pop size 200, num ls 0, time taken: 99.155s
# Task 4, num run 3, pop size 200, num ls 5, time taken: 113.663s
# Task 4, num run 4, pop size 100, num ls 0, time taken: 41.834s
# Task 4, num run 4, pop size 100, num ls 5, time taken: 55.328s
# Task 4, num run 4, pop size 200, num ls 0, time taken: 98.194s
# Task 4, num run 4, pop size 200, num ls 5, time taken: 127.554s

# %% [markdown]
# #### Combinatorial Crossover

# %%
for task_id in range(5):
    run_task_comb("large", task_id=task_id, num_run=5, pop_sizes=[100, 200], num_lss=[0, 10])
